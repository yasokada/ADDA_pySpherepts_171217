# %%
# %matplotlib inline

'''
Dec. 17, 2017
Sample plot of [beta_gamma.tbl]
'''

# v0.2 Dec. 17, 2017
#  - tweak for the display
#  - read [beta_gamma_XXX.tbl]
#  - branched from [triangularVanDerCorput_171017.ipynb]
# v0.1 Oct. 17, 2017
#  - branched from [test_scatter_170812.ipynb]

import numpy as np
from pylab import rcParams
import matplotlib.pyplot as plt
import matplotlib.cm as cm
import sys

rcParams['figure.figsize'] = 6,6
rcParams['figure.dpi'] = 120

# 1. read data
#IN_FILE = 'beta_gamma_gIN.tbl'
IN_FILE = 'beta_gamma_gHN.tbl'
btgm = np.genfromtxt(IN_FILE, delimiter=',')
x, y = [], []
for elem in btgm:
    x += [elem[0]]
    y += [elem[1]]
NUM_DATA = len(x)

color = [10 for idx in range(NUM_DATA)]

# 2. draw data
size = 8  # arbitrary
plt.scatter(x, y, size)
plt.xlim(0, 180)
plt.ylim(0, 360)
plt.xlabel('beta(deg)')
plt.ylabel('gamma(deg)')
